# %%
# !git clone https://github.com/scaryslend/TS-TCC-Replication_And_Analysis /content/drive/MyDrive/Практика_TS-TCC/
# Out:
# fatal: destination path '/content/drive/MyDrive/Практика_TS-TCC' already exists and is not an empty directory.
# ...

# %%
# !pip install mne
# !pip install scikit-learn
# !pip install pandas
# !pip install openpyxl
# !pip install mat4py
# !pip install numpy
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 4, in <module>
#     from pip._internal.cli.main import main
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 11, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/autocompletion.py", line 10, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/build_env.py", line 19, in <module>
# ...

# %%
# %cd /content/drive/MyDrive/Практика_TS-TCC/data_preprocessing/epilepsy
# !python preprocess.py
# Out:
# /content/drive/MyDrive/Практика_TS-TCC/data_preprocessing/epilepsy
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Практика_TS-TCC/data_preprocessing/epilepsy/preprocess.py", line 29, in <module>
#     torch.save(dat_dict, os.path.join(output_dir, "train.pt"))
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1003, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 865, in _open_zipfile_writer
#     return container(name_or_buffer)  # type: ignore[arg-type]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 829, in __init__
#     torch._C.PyTorchFileWriter(
# RuntimeError: Parent directory ../../data/epilepsy does not exist.
# /content/drive/MyDrive/Практика_TS-TCC

# %%
# %cd /content/drive/MyDrive/Практика_TS-TCC/
# Out:
# /content/drive/MyDrive/Практика_TS-TCC

# %%
# Exp 1
# !python main.py --experiment_description Exp1 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp1 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp1 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp1 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 2
# !python main.py --experiment_description Exp2 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp2 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp2 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp2 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 3
# !python main.py --experiment_description Exp3 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp3 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp3 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp3 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1757	 | 	Train Accuracy     : 0.9391
# Valid Loss     : 0.4204	 | 	Valid Accuracy     : 0.8800
#
# Epoch : 2
# Train Loss     : 0.1326	 | 	Train Accuracy     : 0.9518
# Valid Loss     : 0.1776	 | 	Valid Accuracy     : 0.9403
#
# Epoch : 3
# Train Loss     : 0.1111	 | 	Train Accuracy     : 0.9583
# Valid Loss     : 0.1545	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 4
# Train Loss     : 0.1000	 | 	Train Accuracy     : 0.9620
# Valid Loss     : 0.1348	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 5
# Train Loss     : 0.0906	 | 	Train Accuracy     : 0.9667
# Valid Loss     : 0.1301	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 6
# Train Loss     : 0.0803	 | 	Train Accuracy     : 0.9718
# Valid Loss     : 0.1062	 | 	Valid Accuracy     : 0.9598
#
# Epoch : 7
# Train Loss     : 0.0745	 | 	Train Accuracy     : 0.9734
# ...

# %%
# Exp 4
# !python main.py --experiment_description Exp4 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp4 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp4 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp4 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1780	 | 	Train Accuracy     : 0.9385
# Valid Loss     : 0.4707	 | 	Valid Accuracy     : 0.8638
#
# Epoch : 2
# Train Loss     : 0.1320	 | 	Train Accuracy     : 0.9516
# Valid Loss     : 0.2001	 | 	Valid Accuracy     : 0.9369
#
# Epoch : 3
# Train Loss     : 0.1115	 | 	Train Accuracy     : 0.9598
# Valid Loss     : 0.2091	 | 	Valid Accuracy     : 0.9414
#
# Epoch : 4
# Train Loss     : 0.0994	 | 	Train Accuracy     : 0.9630
# Valid Loss     : 0.1584	 | 	Valid Accuracy     : 0.9470
#
# Epoch : 5
# Train Loss     : 0.0913	 | 	Train Accuracy     : 0.9675
# Valid Loss     : 0.1879	 | 	Valid Accuracy     : 0.9431
#
# Epoch : 6
# Train Loss     : 0.0831	 | 	Train Accuracy     : 0.9701
# Valid Loss     : 0.1284	 | 	Valid Accuracy     : 0.9565
#
# Epoch : 7
# Train Loss     : 0.0762	 | 	Train Accuracy     : 0.9722
# ...

# %%
# Exp 5
# !python main.py --experiment_description Exp5 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp5 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp5 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp5 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1837	 | 	Train Accuracy     : 0.9374
# Valid Loss     : 0.4652	 | 	Valid Accuracy     : 0.8650
#
# Epoch : 2
# Train Loss     : 0.1331	 | 	Train Accuracy     : 0.9522
# Valid Loss     : 0.1975	 | 	Valid Accuracy     : 0.9369
#
# Epoch : 3
# Train Loss     : 0.1178	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2042	 | 	Valid Accuracy     : 0.9397
#
# Epoch : 4
# Train Loss     : 0.1002	 | 	Train Accuracy     : 0.9623
# Valid Loss     : 0.1906	 | 	Valid Accuracy     : 0.9425
#
# Epoch : 5
# Train Loss     : 0.0881	 | 	Train Accuracy     : 0.9656
# Valid Loss     : 0.1125	 | 	Valid Accuracy     : 0.9559
#
# Epoch : 6
# Train Loss     : 0.0860	 | 	Train Accuracy     : 0.9685
# Valid Loss     : 0.1002	 | 	Valid Accuracy     : 0.9604
#
# Epoch : 7
# Train Loss     : 0.0791	 | 	Train Accuracy     : 0.9708
# ...

# %%
# Exp 6
# !python main.py --experiment_description Exp6 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp6 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp6 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp6 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1908	 | 	Train Accuracy     : 0.9323
# Valid Loss     : 0.4368	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1382	 | 	Train Accuracy     : 0.9526
# Valid Loss     : 0.1659	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 3
# Train Loss     : 0.1218	 | 	Train Accuracy     : 0.9549
# Valid Loss     : 0.2016	 | 	Valid Accuracy     : 0.9397
#
# Epoch : 4
# Train Loss     : 0.0991	 | 	Train Accuracy     : 0.9627
# Valid Loss     : 0.1711	 | 	Valid Accuracy     : 0.9459
#
# Epoch : 5
# Train Loss     : 0.0928	 | 	Train Accuracy     : 0.9649
# Valid Loss     : 0.1378	 | 	Valid Accuracy     : 0.9526
#
# Epoch : 6
# Train Loss     : 0.0874	 | 	Train Accuracy     : 0.9689
# Valid Loss     : 0.1135	 | 	Valid Accuracy     : 0.9576
#
# Epoch : 7
# Train Loss     : 0.0792	 | 	Train Accuracy     : 0.9700
# ...

# %%
# Exp 7
# !python main.py --experiment_description Exp7 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp7 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp7 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp7 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 8
# !python main.py --experiment_description Exp8 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp8 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp8 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp8 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 9
# !python main.py --experiment_description Exp9 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp9 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp9 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp9 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 10
# !python main.py --experiment_description Exp10 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp10 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp10 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp10 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 11
# !python main.py --experiment_description Exp11 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp11 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp11 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp11 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 12
# !python main.py --experiment_description Exp12 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp12 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp12 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp12 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 13
# !python main.py --experiment_description Exp13 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp13 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp13 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp13 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 14
# !python main.py --experiment_description Exp14 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp14 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp14 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp14 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 15
# !python main.py --experiment_description Exp15 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp15 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp15 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp15 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1699	 | 	Train Accuracy     : 0.9398
# Valid Loss     : 0.2483	 | 	Valid Accuracy     : 0.9180
#
# Epoch : 2
# Train Loss     : 0.1284	 | 	Train Accuracy     : 0.9538
# Valid Loss     : 0.2205	 | 	Valid Accuracy     : 0.9375
#
# Epoch : 3
# Train Loss     : 0.0982	 | 	Train Accuracy     : 0.9633
# Valid Loss     : 0.1654	 | 	Valid Accuracy     : 0.9464
#
# Epoch : 4
# Train Loss     : 0.0911	 | 	Train Accuracy     : 0.9667
# Valid Loss     : 0.1698	 | 	Valid Accuracy     : 0.9498
#
# Epoch : 5
# Train Loss     : 0.0786	 | 	Train Accuracy     : 0.9717
# Valid Loss     : 0.1310	 | 	Valid Accuracy     : 0.9554
#
# Epoch : 6
# Train Loss     : 0.0763	 | 	Train Accuracy     : 0.9731
# Valid Loss     : 0.1711	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0705	 | 	Train Accuracy     : 0.9734
# ...

# %%
# Exp 16
# !python main.py --experiment_description Exp16 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp16 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp16 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp16 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.2252	 | 	Train Accuracy     : 0.9240
# Valid Loss     : 0.5870	 | 	Valid Accuracy     : 0.7941
#
# Epoch : 2
# Train Loss     : 0.1559	 | 	Train Accuracy     : 0.9453
# Valid Loss     : 0.4880	 | 	Valid Accuracy     : 0.8644
#
# Epoch : 3
# Train Loss     : 0.1362	 | 	Train Accuracy     : 0.9503
# Valid Loss     : 0.3093	 | 	Valid Accuracy     : 0.9146
#
# Epoch : 4
# Train Loss     : 0.1276	 | 	Train Accuracy     : 0.9528
# Valid Loss     : 0.2411	 | 	Valid Accuracy     : 0.9263
#
# Epoch : 5
# Train Loss     : 0.1131	 | 	Train Accuracy     : 0.9570
# Valid Loss     : 0.1989	 | 	Valid Accuracy     : 0.9392
#
# Epoch : 6
# Train Loss     : 0.1060	 | 	Train Accuracy     : 0.9597
# Valid Loss     : 0.1672	 | 	Valid Accuracy     : 0.9448
#
# Epoch : 7
# Train Loss     : 0.0959	 | 	Train Accuracy     : 0.9629
# ...

# %%
# Exp 17
# !python main.py --experiment_description Exp17 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp17 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp17 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp17 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.2244	 | 	Train Accuracy     : 0.9190
# Valid Loss     : 0.4046	 | 	Valid Accuracy     : 0.8583
#
# Epoch : 2
# Train Loss     : 0.1568	 | 	Train Accuracy     : 0.9437
# Valid Loss     : 0.2457	 | 	Valid Accuracy     : 0.9152
#
# Epoch : 3
# Train Loss     : 0.1433	 | 	Train Accuracy     : 0.9478
# Valid Loss     : 0.2606	 | 	Valid Accuracy     : 0.9163
#
# Epoch : 4
# Train Loss     : 0.1378	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2291	 | 	Valid Accuracy     : 0.9241
#
# Epoch : 5
# Train Loss     : 0.1263	 | 	Train Accuracy     : 0.9529
# Valid Loss     : 0.1905	 | 	Valid Accuracy     : 0.9347
#
# Epoch : 6
# Train Loss     : 0.1175	 | 	Train Accuracy     : 0.9575
# Valid Loss     : 0.1896	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 7
# Train Loss     : 0.1111	 | 	Train Accuracy     : 0.9575
# ...

# %%
# Exp 18
# !python main.py --experiment_description Exp18 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp18 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp18 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp18 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.2176	 | 	Train Accuracy     : 0.9380
# Valid Loss     : 0.4064	 | 	Valid Accuracy     : 0.8839
#
# Epoch : 2
# Train Loss     : 0.1172	 | 	Train Accuracy     : 0.9586
# Valid Loss     : 0.1639	 | 	Valid Accuracy     : 0.9453
#
# Epoch : 3
# Train Loss     : 0.0902	 | 	Train Accuracy     : 0.9668
# Valid Loss     : 0.1118	 | 	Valid Accuracy     : 0.9570
#
# Epoch : 4
# Train Loss     : 0.0850	 | 	Train Accuracy     : 0.9667
# Valid Loss     : 0.1174	 | 	Valid Accuracy     : 0.9581
#
# Epoch : 5
# Train Loss     : 0.0744	 | 	Train Accuracy     : 0.9731
# Valid Loss     : 0.1362	 | 	Valid Accuracy     : 0.9548
#
# Epoch : 6
# Train Loss     : 0.0685	 | 	Train Accuracy     : 0.9755
# Valid Loss     : 0.1277	 | 	Valid Accuracy     : 0.9576
#
# Epoch : 7
# Train Loss     : 0.0727	 | 	Train Accuracy     : 0.9738
# ...

# %%
# Exp 19
# !python main.py --experiment_description Exp19 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp19 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp19 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp19 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 20
# !python main.py --experiment_description Exp20 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp20 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp20 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp20 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1898	 | 	Train Accuracy     : 0.9353
# Valid Loss     : 0.4375	 | 	Valid Accuracy     : 0.8655
#
# Epoch : 2
# Train Loss     : 0.1358	 | 	Train Accuracy     : 0.9507
# Valid Loss     : 0.2196	 | 	Valid Accuracy     : 0.9286
#
# Epoch : 3
# Train Loss     : 0.1145	 | 	Train Accuracy     : 0.9574
# Valid Loss     : 0.2154	 | 	Valid Accuracy     : 0.9381
#
# Epoch : 4
# Train Loss     : 0.1119	 | 	Train Accuracy     : 0.9600
# Valid Loss     : 0.1485	 | 	Valid Accuracy     : 0.9475
#
# Epoch : 5
# Train Loss     : 0.0920	 | 	Train Accuracy     : 0.9650
# Valid Loss     : 0.1312	 | 	Valid Accuracy     : 0.9520
#
# Epoch : 6
# Train Loss     : 0.0828	 | 	Train Accuracy     : 0.9697
# Valid Loss     : 0.1440	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0825	 | 	Train Accuracy     : 0.9693
# ...

# %%
# Exp 21
# !python main.py --experiment_description Exp21 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp21 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp21 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp21 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1780	 | 	Train Accuracy     : 0.9378
# Valid Loss     : 0.2994	 | 	Valid Accuracy     : 0.8968
#
# Epoch : 2
# Train Loss     : 0.1233	 | 	Train Accuracy     : 0.9544
# Valid Loss     : 0.1315	 | 	Valid Accuracy     : 0.9481
#
# Epoch : 3
# Train Loss     : 0.1011	 | 	Train Accuracy     : 0.9611
# Valid Loss     : 0.1242	 | 	Valid Accuracy     : 0.9498
#
# Epoch : 4
# Train Loss     : 0.0975	 | 	Train Accuracy     : 0.9645
# Valid Loss     : 0.1062	 | 	Valid Accuracy     : 0.9576
#
# Epoch : 5
# Train Loss     : 0.0802	 | 	Train Accuracy     : 0.9698
# Valid Loss     : 0.0865	 | 	Valid Accuracy     : 0.9654
#
# Epoch : 6
# Train Loss     : 0.0725	 | 	Train Accuracy     : 0.9725
# Valid Loss     : 0.0803	 | 	Valid Accuracy     : 0.9693
#
# Epoch : 7
# Train Loss     : 0.0727	 | 	Train Accuracy     : 0.9725
# ...

# %%
# Exp 22
# !python main.py --experiment_description Exp22 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp22 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp22 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# !python main.py --experiment_description Exp22 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1980	 | 	Train Accuracy     : 0.9331
# Valid Loss     : 0.6120	 | 	Valid Accuracy     : 0.8415
#
# Epoch : 2
# Train Loss     : 0.1458	 | 	Train Accuracy     : 0.9485
# Valid Loss     : 0.3566	 | 	Valid Accuracy     : 0.9068
#
# Epoch : 3
# Train Loss     : 0.1264	 | 	Train Accuracy     : 0.9552
# Valid Loss     : 0.3758	 | 	Valid Accuracy     : 0.9152
#
# Epoch : 4
# Train Loss     : 0.1259	 | 	Train Accuracy     : 0.9549
# Valid Loss     : 0.2521	 | 	Valid Accuracy     : 0.9314
#
# Epoch : 5
# Train Loss     : 0.1034	 | 	Train Accuracy     : 0.9616
# Valid Loss     : 0.2341	 | 	Valid Accuracy     : 0.9369
#
# Epoch : 6
# Train Loss     : 0.0940	 | 	Train Accuracy     : 0.9653
# Valid Loss     : 0.2372	 | 	Valid Accuracy     : 0.9386
#
# Epoch : 7
# Train Loss     : 0.0907	 | 	Train Accuracy     : 0.9661
# ...

# %%
# Exp 23
# !python main.py --experiment_description Exp23 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp23 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp23 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file 'main.py': [Errno 107] Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file 'main.py': [Errno 107] Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ...

# %%
# Exp 24
# !python main.py --experiment_description Exp24 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp24 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp24 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203

# %%
# Exp 25
# !python main.py --experiment_description Exp25 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp25 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp25 --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 030203

# %%
# Exp 26
# !python main.py --experiment_description Exp26 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp26 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp26 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1699	 | 	Train Accuracy     : 0.9398
# Valid Loss     : 0.2483	 | 	Valid Accuracy     : 0.9180
#
# Epoch : 2
# Train Loss     : 0.1284	 | 	Train Accuracy     : 0.9538
# Valid Loss     : 0.2205	 | 	Valid Accuracy     : 0.9375
#
# Epoch : 3
# Train Loss     : 0.0982	 | 	Train Accuracy     : 0.9633
# Valid Loss     : 0.1654	 | 	Valid Accuracy     : 0.9464
#
# Epoch : 4
# Train Loss     : 0.0911	 | 	Train Accuracy     : 0.9667
# Valid Loss     : 0.1698	 | 	Valid Accuracy     : 0.9498
#
# Epoch : 5
# Train Loss     : 0.0786	 | 	Train Accuracy     : 0.9717
# Valid Loss     : 0.1310	 | 	Valid Accuracy     : 0.9554
#
# Epoch : 6
# Train Loss     : 0.0763	 | 	Train Accuracy     : 0.9731
# Valid Loss     : 0.1711	 | 	Valid Accuracy     : 0.9509
#
# Epoch : 7
# Train Loss     : 0.0705	 | 	Train Accuracy     : 0.9734
# ...

# %%
# Exp 27
# !python main.py --experiment_description Exp27 --run_description run_1 --selected_dataset Epilepsy --training_mode supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp27 --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 030203
# !python main.py --experiment_description Exp27 --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 030203
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    supervised
# ...
# Data loaded ...
# Training started ....
#
# Epoch : 1
# Train Loss     : 0.1823	 | 	Train Accuracy     : 0.9461
# Valid Loss     : 0.3922	 | 	Valid Accuracy     : 0.9012
#
# Epoch : 2
# Train Loss     : 0.1105	 | 	Train Accuracy     : 0.9630
# Valid Loss     : 0.0840	 | 	Valid Accuracy     : 0.9699
#
# Epoch : 3
# Train Loss     : 0.0864	 | 	Train Accuracy     : 0.9682
# Valid Loss     : 0.1356	 | 	Valid Accuracy     : 0.9554
#
# Epoch : 4
# Train Loss     : 0.0898	 | 	Train Accuracy     : 0.9656
# Valid Loss     : 0.1086	 | 	Valid Accuracy     : 0.9609
#
# Epoch : 5
# Train Loss     : 0.0730	 | 	Train Accuracy     : 0.9727
# Valid Loss     : 0.1044	 | 	Valid Accuracy     : 0.9637
#
# Epoch : 6
# Train Loss     : 0.0683	 | 	Train Accuracy     : 0.9752
# Valid Loss     : 0.0679	 | 	Valid Accuracy     : 0.9715
#
# Epoch : 7
# Train Loss     : 0.0665	 | 	Train Accuracy     : 0.9768
# ...

# %%
# Exp Rand Seed Train
# !python main.py --experiment_description ExpRandSeedL --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 1
# !python main.py --experiment_description ExpRandSeedL --run_description run_1 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 1
# !python main.py --experiment_description ExpRandSeedL --run_description run_2 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 2
# !python main.py --experiment_description ExpRandSeedL --run_description run_2 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 2
# !python main.py --experiment_description ExpRandSeedL --run_description run_3 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 3
# !python main.py --experiment_description ExpRandSeedL --run_description run_3 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 3
# !python main.py --experiment_description ExpRandSeedL --run_description run_4 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 4
# !python main.py --experiment_description ExpRandSeedL --run_description run_4 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 4
# !python main.py --experiment_description ExpRandSeedL --run_description run_5 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 5
# !python main.py --experiment_description ExpRandSeedL --run_description run_5 --selected_dataset Epilepsy --training_mode train_linear --device cuda --seed 5
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    self_supervised
# ...
# Data loaded ...
# Training started ....
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1779: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
#
# Epoch : 1
# Train Loss     : 12.6005	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 2
# Train Loss     : 11.8997	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 3
# Train Loss     : 11.6942	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 4
# Train Loss     : 11.4738	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 5
# Train Loss     : 11.3783	 | 	Train Accuracy     : 0.0000
# ...

# %%
# Exp Rand Seed Train
# !python main.py --experiment_description ExpRandSeedF --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 1
# !python main.py --experiment_description ExpRandSeedF --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 1
# !python main.py --experiment_description ExpRandSeedF --run_description run_2 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 2
# !python main.py --experiment_description ExpRandSeedF --run_description run_2 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 2
# !python main.py --experiment_description ExpRandSeedF --run_description run_3 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 3
# !python main.py --experiment_description ExpRandSeedF --run_description run_3 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 3
# !python main.py --experiment_description ExpRandSeedF --run_description run_4 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 4
# !python main.py --experiment_description ExpRandSeedF --run_description run_4 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 4
# !python main.py --experiment_description ExpRandSeedF --run_description run_5 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 5
# !python main.py --experiment_description ExpRandSeedF --run_description run_5 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 5
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    self_supervised
# ...
# Data loaded ...
# Training started ....
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1779: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
#
# Epoch : 1
# Train Loss     : 12.7433	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 2
# Train Loss     : 12.0709	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 3
# Train Loss     : 11.7431	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 4
# Train Loss     : 11.5791	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 5
# Train Loss     : 11.3166	 | 	Train Accuracy     : 0.0000
# ...

# %%
# Exp Recreate
# !python main.py --experiment_description ExpRe --run_description run_1 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 1
# !python main.py --experiment_description ExpRe --run_description run_1 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 1
# !python main.py --experiment_description ExpRe --run_description run_2 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 2
# !python main.py --experiment_description ExpRe --run_description run_2 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 2
# !python main.py --experiment_description ExpReF --run_description run_3 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 3
# !python main.py --experiment_description ExpRe --run_description run_3 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 3
# !python main.py --experiment_description ExpRe --run_description run_4 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 4
# !python main.py --experiment_description ExpRe --run_description run_4 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 4
# !python main.py --experiment_description ExpRe --run_description run_5 --selected_dataset Epilepsy --training_mode self_supervised --device cuda --seed 5
# !python main.py --experiment_description ExpRe --run_description run_5 --selected_dataset Epilepsy --training_mode fine_tune --device cuda --seed 5
# Out:
# ...
# Dataset: Epilepsy
# Method:  TS-TCC
# Mode:    self_supervised
# ...
# Data loaded ...
# Training started ....
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1779: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
#
# Epoch : 1
# Train Loss     : 12.5297	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 2
# Train Loss     : 11.9195	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 3
# Train Loss     : 11.7292	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 4
# Train Loss     : 11.5519	 | 	Train Accuracy     : 0.0000
# Valid Loss     : 0.0000	 | 	Valid Accuracy     : 0.0000
#
# Epoch : 5
# Train Loss     : 11.5128	 | 	Train Accuracy     : 0.0000
# ...
